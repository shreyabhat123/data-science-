# %%
import pandas as pd
import numpy as np

# %%
bd=pd.read_csv('C:/Users/shubh/Desktop/New folder/StudentsPerformance.csv',sep=',')

# %%
bd.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# ...

# %%
bd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# gender                         1000 non-null object
# race/ethnicity                 1000 non-null object
# parental level of education    1000 non-null object
# lunch                          1000 non-null object
# test preparation course        1000 non-null object
# math score                     1000 non-null int64
# reading score                  1000 non-null int64
# writing score                  1000 non-null int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.distplot(bd['math score'],kde=True)

# %%
sns.distplot(bd['reading score'],kde=True)

# %%
sns.distplot(bd['writing score'],kde=True)

# %%
bd.shape
# Out:
# (1000, 8)

# %%
bd.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
plt.figure(figsize=[10,6])
sns.countplot(x="parental level of education", data=bd, hue = "test preparation course",palette="OrRd")

# %% [markdown]
# Inference: this graph shows that students in every degree have a majority of not completing test preparation for every parental level of education.

# %%
plt.figure(figsize=[10,6])
sns.countplot(x="race/ethnicity", data=bd, hue = "gender",palette="Blues")

# %% [markdown]
# Inference:females of group B and C have performed better
#           females at almost at par with males in group D and E
#           males have performed better  in group A

# %%
plt.figure(figsize=[10,6])
sns.countplot(x="lunch", data=bd, hue = "test preparation course",palette="PuRd")

# %% [markdown]
# Inference: the students who have had standard lunch have done test prepairation course rather than students who have recieved free / reduced prices in lunch.

# %%
plt.figure(figsize=[10,6])
sns.countplot(x="race/ethnicity", data=bd, hue = "lunch",palette="YlGn")

# %% [markdown]
# Inference: all students for all the groups have permofmed better having standard lunch .

# %%
plt.figure(figsize=[10,6])
sns.countplot(x="test preparation course", data=bd, hue = "gender",palette="Greys")

# %% [markdown]
# Inference: Majority of the students have not completed the test preparation course
#            the male and female students are at par on completing the test preparation course.

# %%
plt.figure(figsize=[10,6])
sns.countplot(x="race/ethnicity", data=bd, hue = "test preparation course",palette="YlOrBr")

# %% [markdown]
# Inference : around 50 % of students or more  in all groups have completed test preparation course.

# %%
plt.rcParams['figure.figsize'] = (20,10)
sns.countplot(bd['reading score'],palette='prism')
plt.title('reading Scores',fontsize=20)
plt.show()

# %%
plt.rcParams['figure.figsize'] = (25,10)
sns.countplot(bd['math score'],palette='prism')
plt.title('math scores',fontsize=20)
plt.show()

# %%
plt.rcParams['figure.figsize'] = (20,10)
sns.countplot(bd['writing score'],palette='prism')
plt.title('writing  Scores',fontsize=20)
plt.show()

# %%
plt.figure(figsize=[25,8])
sns.countplot(x="math score", data=bd, hue = "gender",palette="Reds")

# %%
fig= plt.figure(figsize=[10,10])
ax1=fig.add_subplot(2,2,1)
ax1=sns.boxplot(x="gender",y="math score", data=bd,palette="coolwarm")
ax2=fig.add_subplot(2,2,2)
ax2=sns.boxplot(x="gender",y="reading score", data=bd,palette="coolwarm")
ax3=fig.add_subplot(2,2,3)
ax3=sns.boxplot(x="gender",y="writing score", data=bd,palette="coolwarm")

# %% [markdown]
# from the graph we can infer that female students have a better reading and writing scores and male students have better math scores.

# %%
fig= plt.figure(figsize=[10,10])
ax1=fig.add_subplot(2,2,1)
ax1=sns.boxplot(x="race/ethnicity",y="math score", data=bd,palette="coolwarm")
ax2=fig.add_subplot(2,2,2)
ax2=sns.boxplot(x="race/ethnicity",y="reading score", data=bd,palette="coolwarm")
ax3=fig.add_subplot(2,2,3)
ax3=sns.boxplot(x="race/ethnicity",y="writing score", data=bd,palette="coolwarm")

# %% [markdown]
# Inference: The writing scores of all the groups are almost similar except that group A writing scores are little less
#            The reading scores of groupB,C,D are the same and group A reading scores are little less and group E scores are                littel high.
#            The math scores of group B and C are the same and group A math scores are little less and group E scores are                    littel high.

# %%
fig= plt.figure(figsize=[22,11])
ax1=fig.add_subplot(2,2,1)
ax1=sns.boxplot(x="parental level of education",y="math score", data=bd,palette="coolwarm")
ax2=fig.add_subplot(2,2,2)
ax2=sns.boxplot(x="parental level of education",y="reading score", data=bd,palette="coolwarm")
ax3=fig.add_subplot(2,2,3)
ax3=sns.boxplot(x="parental level of education",y="writing score", data=bd,palette="coolwarm")

# %% [markdown]
# Inference: This graph shows that students have almost similar scores for every parental level of education.

# %%
fig= plt.figure(figsize=[20,11])
ax1=fig.add_subplot(2,2,1)
ax1=sns.boxplot(x="lunch",y="math score", data=bd,palette="coolwarm")
ax2=fig.add_subplot(2,2,2)
ax2=sns.boxplot(x="lunch",y="reading score", data=bd,palette="coolwarm")
ax3=fig.add_subplot(2,2,3)
ax3=sns.boxplot(x="lunch",y="writing score", data=bd,palette="coolwarm")

# %% [markdown]
# Inference:The students with standard lunch have better math,reading and writting scores.

# %%
fig= plt.figure(figsize=[20,11])
ax1=fig.add_subplot(2,2,1)
ax1=sns.boxplot(x="test preparation course",y="math score", data=bd,palette="coolwarm")
ax2=fig.add_subplot(2,2,2)
ax2=sns.boxplot(x="test preparation course",y="reading score", data=bd,palette="coolwarm")
ax3=fig.add_subplot(2,2,3)
ax3=sns.boxplot(x="test preparation course",y="writing score", data=bd,palette="coolwarm")

# %% [markdown]
# Inference:students who have completed test peparation  course have better math,reading and writing scores than the students who           did not complete or do test preparation course
